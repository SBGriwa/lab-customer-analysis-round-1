# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the three files into python as dataframes

# %%
df1 = pd.read_csv('/Users/civicfab/Desktop/Documents/Ironhack/Unit1/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv('/Users/civicfab/Desktop/Documents/Ironhack/Unit1/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv('/Users/civicfab/Desktop/Documents/Ironhack/Unit1/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %% [markdown]
# # Concatenate the three dataframes

# %%
data = pd.concat([df1, df2, df3])
data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount', 'State',
#        'Gender'],
#       dtype='object')

# %%
data = pd.concat([df1, df2, df3], axis=1)
data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income Monthly Premium Auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
data.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount', 'Customer', 'ST',
#        'GENDER', 'Education', 'Customer Lifetime Value', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class', 'Customer',
#        'State', 'Customer Lifetime Value', 'Education', 'Gender', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
cols = []

for col in df1.columns:
    lower_cased = col.lower().replace(' ', '_')
    cols.append(lower_cased)

cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
df1.columns = cols

# %%
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in data.columns]

cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount',
#  'customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
for i in range(len(df1.columns)):
    print(df1.columns[i], data.columns[i])
# Out:
# customer Customer
# st ST
# gender GENDER
# education Education
# customer_lifetime_value Customer Lifetime Value
# income Income
# monthly_premium_auto Monthly Premium Auto
# number_of_open_complaints Number of Open Complaints
# policy_type Policy Type
# vehicle_class Vehicle Class
# total_claim_amount Total Claim Amount

# %%
cols = [data.columns[i].lower().replace(' ', '_') for i in range(len(data.columns))]
 
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount',
#  'customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
data.columns = cols
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income monthly_premium_auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
data.columns = data.columns.str.lower()
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income monthly_premium_auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
df1 = df1.rename(columns={'st':'state'})

df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# # Show the DataFrame's shape.

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.shape
# Out:
# (996, 11)

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# # Which columns are categorical?

# %%
df1.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df2.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# dtype: object

# %%
df3.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints      int64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
categoricals = df1.select_dtypes('object')
categoricals
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value number_of_open_complaints     policy_type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %% [markdown]
# # # Which columns are numerical?

# %%
numericals = df1.select_dtypes("number")
numericals
# Out:
#        income  monthly_premium_auto  total_claim_amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 4003      NaN                   NaN                 NaN
# 4004      NaN                   NaN                 NaN
# 4005      NaN                   NaN                 NaN
# 4006      NaN                   NaN                 NaN
# 4007      NaN                   NaN                 NaN
#
# [4008 rows x 3 columns]

# %%
categoricals = data.select_dtypes('object')
categoricals
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value number_of_open_complaints     policy_type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
numericals = data.select_dtypes("number")
numericals
# Out:
#        income  monthly_premium_auto  total_claim_amount   income  \
# 0         0.0                1000.0            2.704934  16061.0
# 1         0.0                  94.0         1131.464935  79487.0
# 2     48767.0                 108.0          566.472247  54230.0
# 3         0.0                 106.0          529.881344  71210.0
# 4     36357.0                  68.0           17.269323  94903.0
# ...       ...                   ...                 ...      ...
# 7065      NaN                   NaN                 NaN      NaN
# 7066      NaN                   NaN                 NaN      NaN
# 7067      NaN                   NaN                 NaN      NaN
# 7068      NaN                   NaN                 NaN      NaN
# 7069      NaN                   NaN                 NaN      NaN
#
#       monthly_premium_auto  total_claim_amount  customer_lifetime_value  \
# 0                     88.0               633.6              3479.137523
# ...

# %% [markdown]
# # Perform the data cleaning operations mentioned so far in class

# %%
data.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount', 'customer', 'st',
#        'gender', 'education', 'customer_lifetime_value', 'income',
#        'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class', 'customer',
#        'state', 'customer_lifetime_value', 'education', 'gender', 'income',
#        'monthly_premium_auto', 'number_of_open_complaints', 'policy_type',
#        'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
data.drop(columns=["education", "number_of_open_complaints"])
# Out:
#      customer          st  gender  customer_lifetime_value   income  \
# 0     RB50392  Washington     NaN                      NaN      0.0
# 1     QZ44356     Arizona       F               697953.59%      0.0
# 2     AI49188      Nevada       F              1288743.17%  48767.0
# 3     WW63253  California       M               764586.18%      0.0
# 4     GA49547  Washington       M               536307.65%  36357.0
# ...       ...         ...     ...                      ...      ...
# 7065      NaN         NaN     NaN                      NaN      NaN
# 7066      NaN         NaN     NaN                      NaN      NaN
# 7067      NaN         NaN     NaN                      NaN      NaN
# 7068      NaN         NaN     NaN                      NaN      NaN
# 7069      NaN         NaN     NaN                      NaN      NaN
#
#      monthly_premium_auto     policy_type  vehicle_class total_claim_amount  \
# ...

# %%
data.drop_duplicates()
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income monthly_premium_auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income monthly_premium_auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# customer                      object
# state                         object
# customer_lifetime_value      float64
# ...

# %%
str
float
int
# Out:
# int

# %%
for i in data['customer_lifetime_value']:
    if type(i) is not str:
        print(i, type(i))

# %%
data.columns = data.columns.str.lower()
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income monthly_premium_auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
df1['income'] <= 0
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 4003    False
# 4004    False
# 4005    False
# 4006    False
# 4007    False
# Name: income, Length: 4008, dtype: bool

# %%
df1[df1['income'] <= 0]
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 1046  RG30482      Oregon      F               College
# 1048  QQ39596     Arizona      F               College
# 1055  KJ86296      Oregon      M  High School or Below
# 1058  UX92071      Oregon      M  High School or Below
# 1061  RY92647        Cali      F              Bachelor
#
#      customer_lifetime_value  income  monthly_premium_auto  \
# 0                        NaN     0.0                1000.0
# 1                 697953.59%     0.0                  94.0
# 3                 764586.18%     0.0                 106.0
# 7                 721610.03%     0.0                 101.0
# ...

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'] * 100

# %%
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#                                 customer_lifetime_value   income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# ...

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# customer                      object
# state                         object
# customer_lifetime_value       object
# ...

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 data['customer_lifetime_value'] = data['customer_lifetime_value'].astype(str).astype(int)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
data[data.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer, st, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount, customer, st, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, total_claim_amount, policy_type, vehicle_class, customer, state, customer_lifetime_value, education, gender, income, monthly_premium_auto, number_of_open_complaints, policy_type, total_claim_amount, vehicle_class]
# Index: []
#
# [0 rows x 33 columns]

# %%
data['income'] <= 0
# Out:
#       income  income  income
# 0       True   False    True
# 1       True   False    True
# 2      False   False   False
# 3       True   False    True
# 4      False   False   False
# ...      ...     ...     ...
# 7065   False   False   False
# 7066   False   False   False
# 7067   False   False    True
# 7068   False   False   False
# 7069   False   False    True
#
# [7070 rows x 3 columns]
